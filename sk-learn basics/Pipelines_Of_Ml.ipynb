# %%
import pandas as pd
import numpy as np
# Load the dataset
df = pd.read_csv("Exact_housing_cleaned_data.csv")
df

df["income_cat"] = pd.cut(df["Median_income"],
                             bins=[0, 1.5, 3.0, 4.5, 6.0, np.inf],
                             labels=[1, 2, 3, 4, 5])

# %%
from sklearn.model_selection import StratifiedShuffleSplit
 
# Assume income_cat is a column in the dataset created from median_income
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
 
for train_index, test_index in split.split(df, df
                                           ["income_cat"]):
    strat_train_set = df.loc[train_index]
    strat_test_set = df.loc[test_index]

# %%
df = strat_train_set.copy()

# %%
housing = strat_train_set.drop("Median_house_value", axis=1)
housing_labels = strat_train_set["Median_house_value"].copy()

# %%
housing = housing.drop("income_cat",axis= 1)

# %%
housing
# Out:
#        Households  Population  Total_rooms  Total_bedrooms  Longitude  \
# 17051         722        2167         2167             751    -122.06
# 17969         823        3131         3131             888    -117.98
# 19243        1098        3527         3527            1170    -117.49
# 16456         673        2197         2197             671    -117.65
# 9074          378         905          905             424    -122.29
# ...           ...         ...          ...             ...        ...
# 17199         736        1573         1573             819    -122.15
# 2148          188         568          568             183    -121.46
# 8646          368        1148         1148             344    -118.11
# 12109         466        1586         1586             491    -122.26
# 10988         431         962          962             447    -117.04
#
#        Latitude  Median_income
# 17051     37.33         7.0102
# 17969     34.07         3.0184
# 19243     34.04         4.1775
# 16456     33.65         7.5426
# 9074      37.91         5.1691
# ...         ...            ...
# 17199     37.73         2.8355
# 2148      38.70         3.8611
# 8646      34.06         2.1061
# 12109     38.16         4.0337
# 10988     32.77         2.7826
#
# [16346 rows x 7 columns]

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %%
mypipeline = Pipeline([
    ("impute",SimpleImputer(Strategy="median")),
    ("standardise",StandardScaler())
    
])

# %%
mypipeline.fit_transform(housing)
# Out:
# array([[ 0.5781    ,  0.64339866,  0.64339866, ..., -1.2386714 ,
#          0.78858959,  1.64867416],
#        [ 0.84121228,  1.48339435,  1.48339435, ...,  0.7982831 ,
#         -0.73705191, -0.44641812],
#        [ 1.55760709,  1.82845482,  1.82845482, ...,  1.04291734,
#         -0.75109156,  0.16193437],
#        ...,
#        [-0.3440955 , -0.2445221 , -0.2445221 , ...,  0.73338014,
#         -0.74173179, -0.92523787],
#        [-0.08879844,  0.13713569,  0.13713569, ..., -1.33852211,
#          1.17701979,  0.08646108],
#        [-0.17997596, -0.40659596, -0.40659596, ...,  1.26758144,
#         -1.34543656, -0.57017752]])
