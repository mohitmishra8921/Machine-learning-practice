# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("strat_train_set.csv").copy()
df
# Out:
#        Households  Population  Total_rooms  Total_bedrooms  Longitude  \
# 0             364         984          984             357    -118.13
# 1             383        1279         1279             372    -117.69
# 2             514        1001         1001             516    -118.43
# 3             769        2831         2831             795    -118.30
# 4             563        1354         1354             607    -122.29
# ...           ...         ...          ...             ...        ...
# 16341         209         657          657             204    -121.33
# 16342         514        1913         1913             562    -118.28
# 16343        1778        4432         4432            2121    -119.74
# 16344         680        1883         1883             667    -117.06
# 16345         392        1011         1011             416    -117.93
#
#        Latitude  Median_income  Median_house_value Ocean_proximity
# ...

# %%
df1 = pd.read_csv("strat_test_set.csv").copy()
df1
# Out:
#       Households  Population  Total_rooms  Total_bedrooms  Longitude  \
# 0            706        2237         2237             797    -121.46
# 1            227        1098         1098             251    -121.65
# 2            579        1975         1975             634    -116.90
# 3            305         662          662             322    -118.34
# 4            853        1992         1992             913    -118.07
# ...          ...         ...          ...             ...        ...
# 4082         185         500          500             192    -121.99
# 4083         354        1052         1052             384    -121.45
# 4084         259        1070         1070             261    -117.15
# 4085         246         616          616             359    -117.72
# 4086        1014        3097         3097            1012    -117.25
#
#       Latitude  Median_income  Median_house_value Ocean_proximity
# 0        38.52         2.1736               72100          INLAND
# ...

# %%
df.plot(kind = "scatter",x = "Longitude",y = "Latitude",cmap ="magma",c = "Median_house_value")
plt.tight_layout()
plt.grid(True)

# %%
from pandas.plotting import scatter_matrix
attributes = ["Median_house_value","Median_income"]
scatter_matrix(df[attributes],figsize=(12,5))
# Out:
# array([[<Axes: xlabel='Median_house_value', ylabel='Median_house_value'>,
#         <Axes: xlabel='Median_income', ylabel='Median_house_value'>],
#        [<Axes: xlabel='Median_house_value', ylabel='Median_income'>,
#         <Axes: xlabel='Median_income', ylabel='Median_income'>]],
#       dtype=object)
